# %%
a=int(input("Enter 1st no:"))
b=int(input("Enter 2nd no:"))
print("sum",a+b)
print("difference",a-b)
print("product",a*b)
# Out:
# Enter 1st no:3
# Enter 2nd no:2
# sum 5
# difference 1
# product 6

# %%
print("quotient",a/b)
print("remainder",a%b)
# Out:
# quotient 1.5
# remainder 1

# %%
r=int(input("Enter radius of circle:"))
area=3.14*r*r
print("Area of circle is:",area)
# Out:
# Enter radius of circle:5
# Area of circle is: 78.5

# %%
a=int(input("Enter 1st no:"))
b=int(input("Enter 2nd no:"))
c=int (input("Enter 3rd no:"))
s=a+b+c
Avg=s/3
print("sum",s)
print("average",Avg)
# Out:
# Enter 1st no:3
# Enter 2nd no:5
# Enter 3rd no:6
# sum 14
# average 4.666666666666667

# %%
cl=int(input("Enter temperature in celcius:"))
fhrt=(cl*9/5)+32
print("temperature in fahrenheit",fhrt)
# Out:
# Enter temperature in celcius:6
# temperature in fahrenheit 42.8

# %%
f=int(input("Enter temperature in fahrenheit:"))
c=(f-32)*5/9
print("Enter temperature in celcius",c)
# Out:
# Enter temperature in fahrenheit:5
# Enter temperature in celcius -15.0

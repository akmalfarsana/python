# %%
n=int(input("enter a number:"))
if n%7==0:
    print("divisible by 7")
else:
    print("do not divisible by 7")
# Out:
# enter a number:4
# do not divisible by 7

# %%
ch=input("enter a character:")
if ch in 'aeiouAEIOU':
    print("it is vowel")
else:
    print("it is not vowel")
# Out:
# enter a character:c
# it is not vowel

# %%
n=int(input("Enter age:"))
if n>=18:
    print("eligible to apply for driving license")
else:
    print("not eligible")
# Out:
# Enter age:17
# not eligible

# %%
a=input("Enter 1st string:")
b=input("Enter 2nd string:")
if a==b:
    print("Two string are equal")
else:
    print("Two string are not equal")
# Out:
# Enter 1st string:r
# Enter 2nd string:b
# Two string are not equal

# %%
n=int(input("Enter purchase amount:"))
if n>5000:
    print("customer is eligible for discount")
else:
    print("not eligible for discount")
# Out:
# Enter purchase amount:4000
# not eligible for discount

# %%
n=int(input("enter a number:"))
if n>10 and n<100:
    print("it lies between 10 and 100")
else:
    print("doesn't lies b/w 10 and 100")
# Out:
# enter a number:26
# it lies between 10 and 100

# %%
n=int(input("Enter attendance percentage:"))
if n>=75:
    print("student is eligible to attend exam")
else:
    print("student is not eligible to attend exam")
# Out:
# Enter attendance percentage:88
# student is eligible to attend exam

# %%
ch=input("Enter an alphabet:")
if ch.isupper():
    print("it is an uppercase")
else:
    print("it is lowercase")
# Out:
# Enter an alphabet:R
# it is an uppercase

# %%
n=int(input("enter a number:"))
if n>=100 and n<1000:
    print("it is a three digit number")
else:
    print("not three digit number")
# Out:
# enter a number:2222
# not three digit number

# %%
n=int(input("Enter amount of mobile data in GB:"))
if n<2:
    print("low usage")
elif n>=2 and n<=5:
    print("moderate usage")
else:
    print("high usage")
# Out:
# Enter amount of mobile data in GB:4
# moderate usage
